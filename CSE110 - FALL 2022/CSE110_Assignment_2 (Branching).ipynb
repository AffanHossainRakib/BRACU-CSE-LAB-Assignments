# %% [markdown]
# [Assignmnet 2 PDF](https://drive.google.com/file/d/1k7jGeKrfRp7_QtjCRp83qrFbMw9VvZEO/view)

# %% [markdown]
# [CSE110_Assignment_2_Branching](https://docs.google.com/document/d/1jyNUc1WfqDjeEr5QsxzF2fMwsJjicEUf/edit)

# %%
#@title Task 1
var1 = int(input('Please enter the first number: '))
var2 = int(input('Please enter the second number: '))
sum = var1+var2
product = var1*var2
difference = var1-var2
print('Sum = ', sum)
print('Product = ', product)
print('Difference = ', difference)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-f9f15b1dadc5> in <module>
#       1 #@title Task 1
# ----> 2 var1 = int(input('Please enter the first number: '))
#       3 var2 = int(input('Please enter the second number: '))
#       4 sum = var1+var2
#       5 product = var1*var2
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
# ...

# %%
#@title Task 2
import math
radius = float(input('Please enter the radius value:'))
area = math.pi*radius**2
print('Area is', area)
circumference = 2*math.pi*radius
print('Circumference is ', circumference)

# %%
#@title Task 3
var1 = float(input('Please enter the first number: '))
var2 = float(input('Please enter the second number: '))
if var1 > var2:
  print('First is greater')
elif var1 < var2:
  print('Second is greater')
else:
  print('The numbers are equal')

# %%
#@title Task 4
var1 = int(input())
var2 = int(input())
if var1 > var2:
  print(var1 - var2)
else:
  print(var2 - var1)

# %%
#@title Task 5
number = int(input())
if number%2==0:
  print('The number is even')
else:
  print('The number is odd')

# %%
#@title Task 6
number = int(input())
if number%2==0 or number%5==0:
  print(number)
else:
  print('Not a multiple of 2 OR 5')

# %%
#@title Task 7
number = int(input())
if number%2 == 0 and number%5 != 0:
  print(number)
elif number%2 != 0 and number%5 == 0:
  print(number)
elif number%2 == 0 and number%5 == 0:
  print('Multiple of 2 and 5 both')
else:
  print('Not a multiple we want')

# %%
#@title Task 8
number = int(input())
if number%2 == 0 and number%5 == 0:
  print(number)
else:
  print('Not multiple of 2 and 5 both')

# %%
#@title Task 9
var1 = int(input())
hours = var1//3600
minutes = (var1%3600)//60
seconds = var1-(hours*3600)-(minutes*60)
print('Hours:',hours,'Minutes:',minutes,'Seconds:',seconds)

# %%
#@title Task 10
work_hours = int(input())
if work_hours < 0:
  print('Hour cannot be negative')
elif work_hours > 168:
  print('Impossible to work more than 168 hours weekly')
elif work_hours <= 40:
  print(work_hours*200)
else:
  print(8000+(work_hours-40)*300)

# %%
#@title Task 11
import math
S = int(input())
if S < 100:
    L = 3000-125*math.pow(S,2)
    print(L)
else:
    L = 12000/(4+math.pow(S,2)/14900)
    print(L)

# %%
#@title Task 12
var1 = int(input())
if var1 < 0 or var1 > 23:
  print('Wrong time')
elif var1 >=4 and var1 <= 6:
  print('Breakfast')
elif var1 >=12 and var1 <=13:
  print('Lunch')
elif var1 >=16 and var1 <=17:
  print('Snacks')
elif var1 >=19 and var1 <=20:
  print('Dinner')
else:
 print('Patience is a virtue')

# %%
#@title Task 13
mark = int(input())
if mark < 0 or mark > 100:
  print()
elif mark >= 90:
  print('A')
elif mark <= 89 and mark >= 80:
  print('B')
elif mark <= 79 and mark >= 70:
  print('C')
elif mark <= 69 and mark >= 60:
  print('D')
elif mark <= 59 and mark >= 50:
  print('E')
else:
  print('F')

# %%
#@title Task 14
distance = float(input())
time = float(input())
speed = (distance/1000)/(time/3600)
if speed < 60:
  print(speed,'km/h\nToo slow. Needs more changes.')
elif speed >= 60 and speed <= 90:
  print(speed,'km/h\nVelocity is okay. The car is ready!')
else:
  print(speed,'km/h\nToo fast. Only a few changes should suffice.')

# %%
#@title Task 15
cgpa = float(input("What's your current CGPA: "))
credits = int(input("Credits completed: "))
if credits >= 30:
    if cgpa == 4.0:
        print('The student is eligible for a waiver of 100 percent.')
    elif cgpa <= 3.99 and cgpa >= 3.95:
        print('The student is eligible for a waiver of 75 percent.')
    elif cgpa <= 3.94 and cgpa >= 3.90:
        print('The student is eligible for a waiver of 50 percent.')
    elif cgpa <= 3.89 and cgpa >= 3.80:
        print('The student is eligible for a waiver of 25 percent.')
    else:
      print('The student is not eligible for a waiver')
else:
    print('The student is not eligible for a waiver')

# %%
#@title Class Task
a = float(input())
b = float(input())
c = float(input())

x1= (-b+(((b**2-4*a*c)**.5)))/(2*a)
x2= (-b-(((b**2-4*a*c)**.5)))/(2*a)
print('x1=', x1)
print('x2=', x2)

# %%
#@title Task 19
var1 = var2 = var3 = var4 = var5 = var6 = False
result1 = result2 = result3 = result4 = result5 = result6 = False
result7 = result8 = result9 = result10 = False
var1 = (not False or False) and True
var2 = var1 and True
var3 = False and not True
var4 = True
var5 = False
var6 = var3 and True
result1 = (var1 and var2) and ( 40 % 3 > 45) or (var5 and var6)
result2 = (var1 or var2) or (result1 and False)
result3 = (var1 and result1) or result2 or var5
result4 = (var1 or var2) or ((var3 and var1) and False)
result5 = (var1 and var2) and (result3 or var1)
result6 = ((var3 or not var2) and (result5)) or True
result7 = (var4 and result1) and ((result1 and False) or True)
result8 = ((var1 and result3) and (not var5 or var6)) and True
result9 = ((result2 and var2) or (not result7 and var1)) and not False
result10 = not (var1 and True)
print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
print(result6)
print(result7)
print(result8)
print(result9)
print(result10)
